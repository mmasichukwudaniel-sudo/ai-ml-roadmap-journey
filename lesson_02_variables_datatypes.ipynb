# %% [markdown]
# <a href="https://colab.research.google.com/github/mmasichukwudaniel-sudo/ai-ml-roadmap-journey/blob/main/lesson_02_variables_datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
patient_name = "Daniel"
patient_age = 34
temperature = 38.5
has_fever = True

print(patient_name)
print(patient_age)
print(temperature)
print(has_fever)
# Out:
# Daniel
# 34
# 38.5
# True

# %%
print(type(patient_name))
# Out:
# <class 'str'>

# %%
print(type(patient_age))
# Out:
# <class 'int'>

# %%
print(type(patient_age))
# Out:
# <class 'int'>

# %%
print(type(patient_age))
# Out:
# <class 'int'>

# %%
print(type(temperature))
print(type(has_fever))
# Out:
# <class 'float'>
# <class 'bool'>

# %%
patient1_name = "Ezeh Emeka"
patient1_age = 35
patient1_weight_kg = 65
patient1_height_m = 1.7
patient1_temperature_celsius = 38.2
patient1_has_fever = True

patient1_bmi = patient1_weight_kg / (patient1_height_m **2)
print("patient1 BMI:", patient1_bmi)


print(type(patient1_name))
print(type(patient1_age))
print(type(patient1_weight_kg))
print(type(patient1_height_m))
print(type(patient1_temperature_celsius))
print(type(patient1_has_fever))
# Out:
# patient1 BMI: 22.49134948096886
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'bool'>

# %%
patient2_name = "Bola Tinubu"
patient2_age = 81
patient2_weight_kg= 70.0
patient2_height_m = 1.6
patient2_temperature_celsius = 35.2
patient2_has_fever = False

print(type(patient2_name))
print(type(patient2_age))
print(type(patient2_weight_kg))
print(type(patient2_height_m))
print(type(patient2_temperature_celsius))
print(type(patient2_has_fever))


patient3_name = "Kenneth Okonkwo"
patient3_age = 62
patient3_weight_kg = 65.1
patient3_height_m = 1.4
patient3_temperature_celsius = 39.0
patient3_has_fever = True

patient2_bmi = patient2_weight_kg / (patient2_height_m **2)
print("patient2_BMI:", patient2_bmi)

patient3_bmi = patient3_weight_kg / (patient3_height_m **2)
print("patient3_BMI:", patient3_bmi)
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'bool'>
# patient2_BMI: 27.343749999999996
# patient3_BMI: 33.214285714285715
