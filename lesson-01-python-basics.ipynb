# %%
print("Hello world")
# Out:
# Hello world

# %%
#This is my name
print("My name is Mmasichukwu Daniel")
#where I live
print("I live in Enugu state")
#My reason for learning AI/ML
print("I want to make the world a better place with the knowledge i will gain from machine learning and Artificial intelligence")
#What I want to build after learning AI/ML
print("I don't know what to build yet but hopefully I will by the time I am done with this course")
# Out:
# My name is Mmasichukwu Daniel
# I live in Enugu state
# I want to make the world a better place with the knowledge i will gain from machine learning and Artificial intelligence
# I don't know what to build yet but hopefully I will by the time I am done with this course

# %%
print("simple calculator")
print("500+350=",500+350)
print("1000-275=",1000-275)
print("12*8=",12*8)
print("100/4=",100/4)
print("2**10=",2**10)
# Out:
# simple calculator
# 500+350= 850
# 1000-275= 725
# 12*8= 96
# 100/4= 25.0
# 2**10= 1024

# %%
#print() displays the output on the screen
#"100" is a string or text data in python while 100 is a number in python
#Syntax error simply means that a grammer rule in python was broken

# %%
print("I am a medical student leaning AI/ML)
print(I love technology")
Print("I will change the world")
# Out:
#   File "/tmp/ipykernel_13860/1634321452.py", line 1
#     print("I am a medical student leaning AI/ML)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print(i love technology)
# Out:
#   File "/tmp/ipykernel_13860/621192638.py", line 1
#     print(i love technology)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
Print("I will change the world")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13860/230833974.py in <cell line: 0>()
# ----> 1 Print("I will change the world")
#
# NameError: name 'Print' is not defined

# %%
print(100+100)
# Out:
# 200

# %%
#print() displays the output on the screen
print(100+100)
print("100+100")
#"100" is a string or text data in python while 100 is a number in python
#Syntax error simply means that a grammer rule in python was broken
# Out:
# 200
# 100+100

# %%
print("100"+"100")
#This cannot add rather the + symbol will only glue the strings together to form a long piece of text
# Out:
# 100100
